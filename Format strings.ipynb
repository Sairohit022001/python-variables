# %%
chicken_biryani_price = 120
veg_biryani_price =  100
egg_biryani_price = 80
format_str = "chicken biryani price is %s,veg biryani price is %s,egg biryani price is %s." %(chicken_biryani_price,veg_biryani_price,egg_biryani_price)
print(format_str)
# Out:
# chicken biryani price is 120,veg biryani price is 100,egg biryani price is 80.

# %%
name = "sai rohit"
place = "hyderabad"
study = "btech"
age = 23
context = "applied to a job"
format_str = "A person name {}, {} years old from {},a {} graduated {}." .format(name,age,place,study,context)
print(format_str)
# Out:
# A person name sai rohit, 23 years old from hyderabad,is a btech graduated applied to a job.

# %%
name = "sai rohit"
place = "hyderabad"
study = "btech"
age = 23
context = "applied to a job"
format_str = f"A person named {name}, {age} years old from {place}, a {study} graduate {context}."
print(format_str)
# Out:
# A person named sai rohit, 23 years old from hyderabad, a btech graduate applied to a job.

# %%
order_1 = "one plate chicken biryani"
order_2 = "with extra masala"
order_3 = "get me a cool water bottle"
bill = "Sir your total bill is five hundred rupees"
format_str1 = "sir,order please,%s,with any specifications sir? %s,do you need any other items? %s,%s." %(order_1,order_2,order_3,bill)
print(format_str1)
# Out:
# sir,order please,one plate chicken biryani,with any specifications sir? with extra masala,do you need any other items? get me a cool water bottle,Sir your total bill is five hundred rupees.

# %%
format_str2 = "sir,order please,{},with any specifications sir? {},do you need any other items? {},{}." .format(order_1,order_2,order_3,bill)
print(format_str2)
# Out:
# sir,order please,one plate chicken biryani,with any specifications sir? with extra masala,do you need any other items? get me a cool water bottle,Sir your total bill is five hundred rupees.

# %%
format_str3 = f"sir,order please,{order_1},with any specifications sir? {order_2},do you need any other items? {order_3},{bill}."
print(format_str3)
# Out:
# sir,order please,one plate chicken biryani,with any specifications sir? with extra masala,do you need any other items? get me a cool water bottle,Sir your total bill is five hundred rupees.
